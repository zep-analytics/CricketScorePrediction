# %%
import pandas as pd
import numpy as np
from prophet import Prophet
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data = pd.read_csv('Virat Kohli - One Day Internationals - Performance Analysis by Year - Sheet1.csv')
data = pd.read_csv('Rohit Sharma - Sheet1.csv')

# %%
data
# Out:
#        Year  Mat  Inns  NO  100s  50s  0s    HS  Runs    Avg     S/R  Ca  St
# 0      2007    4     3   0     0    1   0    52    61  20.33   82.43   3   0
# 1      2008   28    28   7     0    3   2   70*   532  25.33   72.58   8   0
# 2      2009    9     7   3     0    0   1   43*   102  25.50   65.81   7   0
# 3      2010   15    14   1     2    1   2   114   504  38.77   86.01   5   0
# 4      2011   16    16   5     0    6   0    95   611  55.55   82.68   3   0
# 5      2012   14    13   0     0    1   3    68   168  12.92   66.93   6   0
# 6      2013   28    27   4     2    8   0   209  1196  52.00   80.81   6   0
# 7      2014   12    12   1     1    3   0   264   578  52.55   94.29   5   0
# 8      2015   17    17   1     3    4   2   150   815  50.94   95.43   6   0
# 9      2016   10    10   1     2    2   0  171*   564  62.67   95.27   5   0
# 10     2017   21    21   3     6    5   1  208*  1293  71.83   99.46   4   0
# 11     2018   19    19   5     5    3   1   162  1030  73.57  100.10  11   0
# 12     2019   28    27   1     7    6   1   159  1490  57.31   89.92   8   0
# 13     2020    3     3   0     1    0   0   119   171  57.00   91.44   0   0
# 14     2021    3     3   0     0    0   0    37    90  30.00   86.54   1   0
# 15     2022    8     8   2     0    3   1   76*   249  41.50  114.22   6   0
# 16  Overall  235   228  34    29   46  14   264  9454  48.73   89.42  84   0

# %% [markdown]
# Forecasting the S/R for next year

# %%
df = data[['Year','S/R']]

# %%
df = df[:-1]

# %%
df
# Out:
#     Year     S/R
# 0   2007   82.43
# 1   2008   72.58
# 2   2009   65.81
# 3   2010   86.01
# 4   2011   82.68
# 5   2012   66.93
# 6   2013   80.81
# 7   2014   94.29
# 8   2015   95.43
# 9   2016   95.27
# 10  2017   99.46
# 11  2018  100.10
# 12  2019   89.92
# 13  2020   91.44
# 14  2021   86.54
# 15  2022  114.22

# %%
df.rename(columns={'Year': 'ds', 'S/R': 'y'}, inplace=True)

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df['y_orig'] = df['y'] # to save a copy of the original data..you'll see why shortly. 
df['y'] = np.log(df['y'])

# %%
df
# Out:
#            ds         y  y_orig
# 0  2007-01-01  4.411949   82.43
# 1  2008-01-01  4.284689   72.58
# 2  2009-01-01  4.186772   65.81
# 3  2010-01-01  4.454464   86.01
# 4  2011-01-01  4.414978   82.68
# 5  2012-01-01  4.203647   66.93
# 6  2013-01-01  4.392101   80.81
# 7  2014-01-01  4.546375   94.29
# 8  2015-01-01  4.558393   95.43
# 9  2016-01-01  4.556715   95.27
# 10 2017-01-01  4.599756   99.46
# 11 2018-01-01  4.606170  100.10
# 12 2019-01-01  4.498920   89.92
# 13 2020-01-01  4.515683   91.44
# 14 2021-01-01  4.460607   86.54
# 15 2022-01-01  4.738126  114.22

# %%
model = Prophet() #instantiate Prophet
model.fit(df)
# Out:
# 18:01:09 - cmdstanpy - INFO - Chain [1] start processing
# 18:01:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
future_data = model.make_future_dataframe(periods=1, freq='Y')

# %%
future_data
# Out:
#            ds
# 0  2007-01-01
# 1  2008-01-01
# 2  2009-01-01
# 3  2010-01-01
# 4  2011-01-01
# 5  2012-01-01
# 6  2013-01-01
# 7  2014-01-01
# 8  2015-01-01
# 9  2016-01-01
# 10 2017-01-01
# 11 2018-01-01
# 12 2019-01-01
# 13 2020-01-01
# 14 2021-01-01
# 15 2022-01-01
# 16 2022-12-31

# %%
forecast_data = model.predict(future_data)

# %%
forecast_data[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#            ds      yhat  yhat_lower  yhat_upper
# 7  2014-01-01  4.510320    4.410678    4.603324
# 8  2015-01-01  4.528040    4.429846    4.635260
# 9  2016-01-01  4.436519    4.335631    4.532724
# 10 2017-01-01  4.471190    4.360369    4.564842
# 11 2018-01-01  4.597995    4.495081    4.699383
# 12 2019-01-01  4.615539    4.509577    4.723424
# 13 2020-01-01  4.523848    4.422894    4.632658
# 14 2021-01-01  4.558460    4.468126    4.657591
# 15 2022-01-01  4.685265    4.586000    4.785590
# 16 2022-12-31  3.596475    3.495683    3.699552

# %%
model.plot(forecast_data)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# C:\Users\ASUS\anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
model.plot_components(forecast_data)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# C:\Users\ASUS\anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
forecast_data_orig = forecast_data # make sure we save the original forecast data
forecast_data_orig['yhat'] = np.exp(forecast_data_orig['yhat'])
forecast_data_orig['yhat_lower'] = np.exp(forecast_data_orig['yhat_lower'])
forecast_data_orig['yhat_upper'] = np.exp(forecast_data_orig['yhat_upper'])

# %%
model.plot(forecast_data_orig)

# %%
df['y_log']=df['y'] #copy the log-transformed data to another column
df['y']=df['y_orig']

# %%
final_df = pd.DataFrame(forecast_data_orig)

# %%
import plotly.graph_objs as go
import plotly.offline as py
#Plot predicted and actual line graph with X=dates, Y=Outbound
actual_chart = go.Scatter(y=df["y_orig"], name= 'Actual')
predict_chart = go.Scatter(y=final_df["yhat"], name= 'Predicted')
predict_chart_upper = go.Scatter(y=final_df["yhat_upper"], name= 'Predicted Upper')
predict_chart_lower = go.Scatter(y=final_df["yhat_lower"], name= 'Predicted Lower')
py.plot([actual_chart, predict_chart, predict_chart_upper, predict_chart_lower])
# Out:
# 'temp-plot.html'

# %%
df
# Out:
#            ds       y  y_orig     y_log
# 0  2007-01-01   82.43   82.43  4.411949
# 1  2008-01-01   72.58   72.58  4.284689
# 2  2009-01-01   65.81   65.81  4.186772
# 3  2010-01-01   86.01   86.01  4.454464
# 4  2011-01-01   82.68   82.68  4.414978
# 5  2012-01-01   66.93   66.93  4.203647
# 6  2013-01-01   80.81   80.81  4.392101
# 7  2014-01-01   94.29   94.29  4.546375
# 8  2015-01-01   95.43   95.43  4.558393
# 9  2016-01-01   95.27   95.27  4.556715
# 10 2017-01-01   99.46   99.46  4.599756
# 11 2018-01-01  100.10  100.10  4.606170
# 12 2019-01-01   89.92   89.92  4.498920
# 13 2020-01-01   91.44   91.44  4.515683
# 14 2021-01-01   86.54   86.54  4.460607
# 15 2022-01-01  114.22  114.22  4.738126

# %%
future_data
# Out:
#            ds
# 0  2008-01-01
# 1  2009-01-01
# 2  2010-01-01
# 3  2011-01-01
# 4  2012-01-01
# 5  2013-01-01
# 6  2014-01-01
# 7  2015-01-01
# 8  2016-01-01
# 9  2017-01-01
# 10 2018-01-01
# 11 2019-01-01
# 12 2020-01-01
# 13 2021-01-01
# 14 2022-01-01
# 15 2022-12-31

# %%
forecast_data
# Out:
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  2007-01-01 -4.855916   70.284018   85.896833    -4.855916    -4.855916
# 1  2008-01-01 -4.833938   64.095493   78.434493    -4.833938    -4.833938
# 2  2009-01-01 -4.811899   66.411670   81.495570    -4.811899    -4.811899
# 3  2010-01-01 -4.789920   75.326005   92.097373    -4.789920    -4.789920
# 4  2011-01-01 -4.767942   77.027168   93.292487    -4.767942    -4.767942
# 5  2012-01-01 -4.745963   69.964919   85.713220    -4.745963    -4.745963
# 6  2013-01-01 -4.723925   72.352735   88.424820    -4.723925    -4.723925
# 7  2014-01-01 -4.701946   82.682577  100.740769    -4.701946    -4.701946
# 8  2015-01-01 -4.679968   83.626184  102.413885    -4.679968    -4.679968
# 9  2016-01-01 -4.657996   76.580398   93.292094    -4.657996    -4.657996
# 10 2017-01-01 -4.636074   79.367897   96.423758    -4.636074    -4.636074
# 11 2018-01-01 -4.614271   89.277555  109.079685    -4.614271    -4.614271
# 12 2019-01-01 -4.592469   91.453119  112.131564    -4.592469    -4.592469
# 13 2020-01-01 -4.570666   83.140250  101.661288    -4.570666    -4.570666
# 14 2021-01-01 -4.548804   86.680523  105.426679    -4.548804    -4.548804
# 15 2022-01-01 -4.527001   98.068522  119.845845    -4.527001    -4.527001
# 16 2022-12-31 -4.505258   33.063811   40.314789    -4.505267    -4.505248
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         9.208007              9.208007              9.208007  9.208007
# 1         9.094514              9.094514              9.094514  9.094514
# 2         9.107264              9.107264              9.107264  9.107264
# 3         9.212266              9.212266              9.212266  9.212266
# 4         9.208007              9.208007              9.208007  9.208007
# 5         9.094514              9.094514              9.094514  9.094514
# 6         9.107264              9.107264              9.107264  9.107264
# 7         9.212266              9.212266              9.212266  9.212266
# 8         9.208007              9.208007              9.208007  9.208007
# 9         9.094514              9.094514              9.094514  9.094514
# 10        9.107264              9.107264              9.107264  9.107264
# 11        9.212266              9.212266              9.212266  9.212266
# 12        9.208007              9.208007              9.208007  9.208007
# 13        9.094514              9.094514              9.094514  9.094514
# 14        9.107264              9.107264              9.107264  9.107264
# 15        9.212266              9.212266              9.212266  9.212266
# 16        8.101734              8.101734              8.101734  8.101734
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0       9.208007      9.208007                   0.0
# 1       9.094514      9.094514                   0.0
# 2       9.107264      9.107264                   0.0
# 3       9.212266      9.212266                   0.0
# 4       9.208007      9.208007                   0.0
# 5       9.094514      9.094514                   0.0
# 6       9.107264      9.107264                   0.0
# 7       9.212266      9.212266                   0.0
# 8       9.208007      9.208007                   0.0
# 9       9.094514      9.094514                   0.0
# 10      9.107264      9.107264                   0.0
# 11      9.212266      9.212266                   0.0
# 12      9.208007      9.208007                   0.0
# 13      9.094514      9.094514                   0.0
# 14      9.107264      9.107264                   0.0
# 15      9.212266      9.212266                   0.0
# 16      8.101734      8.101734                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                          0.0                         0.0   77.640660
# 1                          0.0                         0.0   70.850828
# 2                          0.0                         0.0   73.358955
# 3                          0.0                         0.0   83.291437
# 4                          0.0                         0.0   84.780498
# 5                          0.0                         0.0   77.366273
# 6                          0.0                         0.0   80.105047
# 7                          0.0                         0.0   90.950920
# 8                          0.0                         0.0   92.576896
# 9                          0.0                         0.0   84.480314
# 10                         0.0                         0.0   87.460726
# 11                         0.0                         0.0   99.285057
# 12                         0.0                         0.0  101.042269
# 13                         0.0                         0.0   92.189700
# 14                         0.0                         0.0   95.436386
# 15                         0.0                         0.0  108.338994
# 16                         0.0                         0.0   36.469468
